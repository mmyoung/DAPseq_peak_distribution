# %%
import pandas as pd
from glob import glob
import os
# import pyBigWig
import numpy as np
from scipy import stats
from collections import defaultdict
from collections import Counter
from operator import itemgetter

# %%
# change this to point at the plant multidap data directory on your filesystem
# data_base_dir = '/clusterfs/jgi/groups/gentech/seqtech/plant_multidap_data'

# %%
ortho_table = pd.read_csv('/clusterfs/jgi/groups/gentech/seqtech/plant_multidap_data/orthofinder/plant_4sp_orthofinder/ath-bol-crub-alyr-4species_orthology_table.tsv', sep='\t')

display(ortho_table.head(5))

ortho_table_by_species = {}
for species, group in ortho_table.groupby('species'):
    ortho_table_by_species[species] = group
    
orthogroup_sizes = ortho_table.groupby(['species', 'orthogroup'])['gene'].agg('count').sort_index()
display(orthogroup_sizes)

n_species_by_orthogroup = ortho_table.groupby('orthogroup')['species'].agg('nunique')
display(n_species_by_orthogroup)

organelle_orthogroup_file = os.path.join('/clusterfs/jgi/groups/gentech/homes/amoralescruz/multidap/N10/peak_annotations/organelle_OGs/10sp_organelle_orthogroups.txt')
organelle_orthogroups = pd.read_csv(organelle_orthogroup_file, header=None, names=['orthogroup'])
organelle_orthogroups = organelle_orthogroups['orthogroup']
# Out:
#                        species orthogroup      protein_id  single_copy_ortho  \
# 0  Brassica_oleracea_TO1000DH3  OG0000000  XP_013583255.1              False
# 1  Brassica_oleracea_TO1000DH3  OG0000000  XP_013583261.1              False
# 2  Brassica_oleracea_TO1000DH3  OG0000000  XP_013583306.1              False
# 3  Brassica_oleracea_TO1000DH3  OG0000000  XP_013583330.1              False
# 4  Brassica_oleracea_TO1000DH3  OG0000000  XP_013583428.1              False
#
#            gene
# 0  LOC106292183
# 1  LOC106292191
# 2  LOC106292247
# 3  LOC106292274
# 4  LOC106292382
# species                         orthogroup
# Arabidopsis_lyrata_MN47         OG0000003     2
#                                 OG0000004     1
#                                 OG0000005     1
#                                 OG0000007     1
#                                 OG0000009     1
#                                              ..
# Capsella_rubella_Monte_Gargano  OG0022947     2
#                                 OG0022948     2
#                                 OG0022949     2
#                                 OG0022950     2
#                                 OG0022951     2
# Name: gene, Length: 82230, dtype: int64
# orthogroup
# OG0000000    1
# OG0000001    1
# OG0000002    2
# OG0000003    2
# OG0000004    2
#             ..
# OG0022947    1
# OG0022948    1
# OG0022949    1
# OG0022950    1
# OG0022951    1
# Name: species, Length: 22952, dtype: int64

# %%
ortho_table['species'].unique()
# Out:
# array(['Brassica_oleracea_TO1000DH3', 'Arabidopsis_thaliana_Col-0',
#        'Arabidopsis_lyrata_MN47', 'Capsella_rubella_Monte_Gargano'],
#       dtype=object)

# %%
##### peak multiN10 dataset
annt_peaks = '/clusterfs/jgi/groups/gentech/homes/amoralescruz/multidap/2_AtAlCrBo/gene_assignment/annotated_tsvs/'

peak_files_annotated = []

for f in glob(os.path.join(annt_peaks, '*_assigned_genes_mRNA_annotated.tsv')):
    f_split = os.path.basename(f).split('_', maxsplit=4)
    tf = f_split[0]
    library_name = os.path.basename(f).replace('_assigned_genes_mRNA_annotated.tsv', '')
    species = '_'.join(itemgetter(*[1,2,3])(f_split))
    species = species.replace('A_lyrata_MN47', 'Arabidopsis_lyrata_MN47')
    species = species.replace('A_thaliana_Col-0', 'Arabidopsis_thaliana_Col-0')
    species = species.replace('B_oleracea_TO1000DH3', 'Brassica_oleracea_TO1000DH3')
    species = species.replace('C_rubella_Monte', 'Capsella_rubella_Monte_Gargano')

    
    peak_files_annotated.append({
        'species': species,
        'tf': tf,
        'library_name': library_name,
        'annotated_peak_file': f
    })

peak_files_annotated_df = pd.DataFrame(peak_files_annotated)

# tfs_passed_all_filters = pd.read_csv('/clusterfs/jgi/groups/gentech/homes/amoralescruz/multidap/tfs_passed_all_filters.txt', header=None, names=['tf'])
#tfs_passed_all_filters = pd.read_csv('/clusterfs/jgi/groups/gentech/homes/amoralescruz/multidap/N10/peak_annotations/N10_T1_tfs.txt', header=None, names=['tf'])

#peak_files_annotated_df = peak_files_annotated_df[peak_files_annotated_df['tf'].isin(tfs_passed_all_filters['tf'])]

peak_files_annotated_df.head(20)
# Out:
#                            species         tf  \
# 0          Arabidopsis_lyrata_MN47  AT1G01060
# 1       Arabidopsis_thaliana_Col-0  AT1G01060
# 2      Brassica_oleracea_TO1000DH3  AT1G01060
# 3   Capsella_rubella_Monte_Gargano  AT1G01060
# 4          Arabidopsis_lyrata_MN47  AT1G01250
# 5       Arabidopsis_thaliana_Col-0  AT1G01250
# 6      Brassica_oleracea_TO1000DH3  AT1G01250
# 7   Capsella_rubella_Monte_Gargano  AT1G01250
# 8          Arabidopsis_lyrata_MN47  AT1G01720
# 9       Arabidopsis_thaliana_Col-0  AT1G01720
# 10     Brassica_oleracea_TO1000DH3  AT1G01720
# 11  Capsella_rubella_Monte_Gargano  AT1G01720
# 12         Arabidopsis_lyrata_MN47  AT1G02230
# 13      Arabidopsis_thaliana_Col-0  AT1G02230
# 14     Brassica_oleracea_TO1000DH3  AT1G02230
# 15  Capsella_rubella_Monte_Gargano  AT1G02230
# 16         Arabidopsis_lyrata_MN47  AT1G02250
# 17      Arabidopsis_thaliana_Col-0  AT1G02250
# 18     Brassica_oleracea_TO1000DH3  AT1G02250
# 19  Capsella_rubella_Monte_Gargano  AT1G02250
#
#                                          library_name  \
# 0   AT1G01060_A_lyrata_MN47_DAPi709D10-ORGi5038-96...
# 1   AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...
# 2   AT1G01060_B_oleracea_TO1000DH3_DAPi709D10-ORGi...
# 3   AT1G01060_C_rubella_Monte_Gargano_DAPi709D10-O...
# 4   AT1G01250_A_lyrata_MN47_DAPi710B07-ORGi5038-96...
# 5   AT1G01250_A_thaliana_Col-0_DAPi710B07-ORGi5005...
# 6   AT1G01250_B_oleracea_TO1000DH3_DAPi710B07-ORGi...
# 7   AT1G01250_C_rubella_Monte_Gargano_DAPi710B07-O...
# 8   AT1G01720_A_lyrata_MN47_DAPi709F09-ORGi5038-96...
# 9   AT1G01720_A_thaliana_Col-0_DAPi709F09-ORGi5005...
# 10  AT1G01720_B_oleracea_TO1000DH3_DAPi709F09-ORGi...
# 11  AT1G01720_C_rubella_Monte_Gargano_DAPi709F09-O...
# 12  AT1G02230_A_lyrata_MN47_DAPi712B03-ORGi5038-96...
# 13  AT1G02230_A_thaliana_Col-0_DAPi712B03-ORGi5005...
# 14  AT1G02230_B_oleracea_TO1000DH3_DAPi712B03-ORGi...
# 15  AT1G02230_C_rubella_Monte_Gargano_DAPi712B03-O...
# 16  AT1G02250_A_lyrata_MN47_DAPi710D09-ORGi5038-96...
# 17  AT1G02250_A_thaliana_Col-0_DAPi710D09-ORGi5005...
# 18  AT1G02250_B_oleracea_TO1000DH3_DAPi710D09-ORGi...
# 19  AT1G02250_C_rubella_Monte_Gargano_DAPi710D09-O...
#
#                                   annotated_peak_file
# 0   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 2   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 3   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 4   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 5   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 6   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 7   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 8   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 9   /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 10  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 11  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 12  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 13  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 14  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 15  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 16  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 17  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 18  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 19  /clusterfs/jgi/groups/gentech/homes/amoralescr...

# %% [markdown]
# ## Selecting only TFs from the allowlist (TFs after FRIP, coverage and other filters)

# %%
allowlist = pd.read_csv('/clusterfs/jgi/groups/gentech/seqtech/plant_multidap_data/library_filtering/library_allowlist.tsv', sep='\t')
allowlist_libnames = allowlist['library_name'].tolist()


peak_files_annotated_df = peak_files_annotated_df[peak_files_annotated_df['library_name'].isin(allowlist_libnames)]
display(peak_files_annotated_df)
# Out:
#                              species         tf  \
# 0            Arabidopsis_lyrata_MN47  AT1G01060
# 1         Arabidopsis_thaliana_Col-0  AT1G01060
# 2        Brassica_oleracea_TO1000DH3  AT1G01060
# 3     Capsella_rubella_Monte_Gargano  AT1G01060
# 4            Arabidopsis_lyrata_MN47  AT1G01250
# ...                              ...        ...
# 1466  Capsella_rubella_Monte_Gargano  AT5G67300
# 1467         Arabidopsis_lyrata_MN47  AT5G67580
# 1468      Arabidopsis_thaliana_Col-0  AT5G67580
# 1469     Brassica_oleracea_TO1000DH3  AT5G67580
# 1470  Capsella_rubella_Monte_Gargano  AT5G67580
#
#                                            library_name  \
# 0     AT1G01060_A_lyrata_MN47_DAPi709D10-ORGi5038-96...
# 1     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...
# 2     AT1G01060_B_oleracea_TO1000DH3_DAPi709D10-ORGi...
# 3     AT1G01060_C_rubella_Monte_Gargano_DAPi709D10-O...
# 4     AT1G01250_A_lyrata_MN47_DAPi710B07-ORGi5038-96...
# ...                                                 ...
# 1466  AT5G67300_C_rubella_Monte_Gargano_DAPi711B01-O...
# 1467  AT5G67580_A_lyrata_MN47_DAPi711D05-ORGi5038-96...
# 1468  AT5G67580_A_thaliana_Col-0_DAPi711D05-ORGi5005...
# 1469  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...
# 1470  AT5G67580_C_rubella_Monte_Gargano_DAPi711D05-O...
#
#                                     annotated_peak_file
# 0     /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1     /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 2     /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 3     /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 4     /clusterfs/jgi/groups/gentech/homes/amoralescr...
# ...                                                 ...
# 1466  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1467  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1468  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1469  /clusterfs/jgi/groups/gentech/homes/amoralescr...
# 1470  /clusterfs/jgi/groups/gentech/homes/amoralescr...
#
# [976 rows x 4 columns]

# %%
len(peak_files_annotated_df['tf'].unique())
# Out:
# 244

# %%
list(peak_files_annotated_df['species'].unique())
# Out:
# ['Arabidopsis_lyrata_MN47',
#  'Arabidopsis_thaliana_Col-0',
#  'Brassica_oleracea_TO1000DH3',
#  'Capsella_rubella_Monte_Gargano']

# %%
def FilterAssigned(assigned, ALLOWED_REGIONS, MIN_PEAK_FOLDCH, MIN_PEAK_FOLDCH_FRAC_OF_BEST,
                   FILTER_DIST_START, MIN_DIST_START, MAX_DIST_START,
                   FILTER_DIST_END, MIN_DIST_END, MAX_DIST_END,
                   MAX_GENE_TARGETS, ONE_PEAK_PER_TARGET):
    
    assigned = assigned[assigned['annotated_peak_region'].isin(ALLOWED_REGIONS)]
    assigned = assigned[assigned['peak_foldch'] >= MIN_PEAK_FOLDCH]

    best_peak_foldch = assigned['peak_foldch'].max()
    min_peak_foldch_dynamic = MIN_PEAK_FOLDCH_FRAC_OF_BEST * best_peak_foldch
    assigned = assigned[assigned['peak_foldch'] >= min_peak_foldch_dynamic]
    
    if FILTER_DIST_START:
        assigned = assigned[assigned['summit_to_cds_start'] >= MIN_DIST_START]
        assigned = assigned[assigned['summit_to_cds_start'] <= MAX_DIST_START]
    if FILTER_DIST_END:
        assigned = assigned[assigned['summit_to_cds_end'] >= MIN_DIST_END]
        assigned = assigned[assigned['summit_to_cds_end'] <= MAX_DIST_END]
    
    if ONE_PEAK_PER_TARGET:
        assigned = assigned.sort_values(by='peak_foldch', ascending=False)
        assigned = assigned.drop_duplicates(subset=['feature_desc'], keep='first')
    
    assigned = assigned.sort_values(by='peak_foldch', ascending=False)
    assigned = assigned.head(MAX_GENE_TARGETS)
    
    return assigned

def GetGffDescValue(gene_desc, key):
    for tag in gene_desc.strip().split(';'):
        k, v = tag.split('=', maxsplit=1)
        if k == key:
            return v
        
def ExtractTargetIds(peaks, key):
    peaks['target_id'] = peaks['feature_desc'].apply(lambda x: GetGffDescValue(x, key))
    return peaks

def ReadFilterPeakFiles(peakfiles_group, species_order, peak_filter_params):
    peakfiles_group = peakfiles_group.set_index('species', drop=True)
    peakfiles_group = peakfiles_group.reindex(species_order).dropna()
        
    peaks_by_species = {}

    for species in peakfiles_group.index:
        peakfile_path = peakfiles_group.loc[species,'annotated_peak_file']
        peaks = pd.read_csv(peakfile_path, sep='\t')
        
        peaks = FilterAssigned(peaks, **peak_filter_params)
        
        peaks_by_species[species] = peaks

    return peaks_by_species

def AssignOrthogroupsToPeaksBySpecies(peaks_by_species, ortho_table_by_species, single_copy_only, organelle_orthogroups):
    peaks_orthogroups_by_species = {}
    for species, peaks in peaks_by_species.items():
        peaks_orthogroups = AssignOrthogroups(peaks, ortho_table_by_species, species, single_copy_only, organelle_orthogroups)
        # if single_copy_only:
        #     peaks_orthogroups = peaks_orthogroups[peaks_orthogroups['single_copy_ortho'] == True].reset_index(drop=True)
        peaks_orthogroups_by_species[species] = peaks_orthogroups
        
    return peaks_orthogroups_by_species
    
def AssignOrthogroups(peaks, ortho_table_by_species, species, single_copy_only, organelle_orthogroups):
    
    if species == 'Brassica_oleracea_TO1000DH3':
        ortho_table_key = 'gene'
        feature_desc_key = 'gene'
    else:
        ortho_table_key = 'protein_id'
        feature_desc_key = 'Name'
        
    peaks = ExtractTargetIds(peaks, feature_desc_key)
    
    ortho_table = ortho_table_by_species[species]
    
    if single_copy_only:
        ortho_table = ortho_table[ortho_table['single_copy_ortho'] == True]
    
    ### remove organelle orthos
    ortho_table = ortho_table[~ortho_table['orthogroup'].isin(organelle_orthogroups)]
    
    peaks = pd.merge(peaks, ortho_table, left_on='target_id', right_on=ortho_table_key, how='inner').reset_index(drop=True)

    return peaks

def FormatSpeciesName(sp):
    sp = sp.split('_')
    # return f"{sp[0][0]}. {' '.join(sp[1:])}"
    return f"{sp[0][0]}. {sp[1]}"

# %%
peak_filter_params = {
    'ALLOWED_REGIONS': ['downstream', 'utr3prime', 'cds', 'intron'],
    'MIN_PEAK_FOLDCH': 5,
    'MIN_PEAK_FOLDCH_FRAC_OF_BEST': 0,
    'FILTER_DIST_START': False,
    'MIN_DIST_START': 0,
    'MAX_DIST_START': 0,
    'FILTER_DIST_END': True,
    'MIN_DIST_END': -500,
    'MAX_DIST_END': 2000,
    'MAX_GENE_TARGETS': 10000000,
    'ONE_PEAK_PER_TARGET': False
}

species_order = ['Arabidopsis_thaliana_Col-0',
                 'Arabidopsis_lyrata_MN47',
                 'Capsella_rubella_Monte_Gargano',
                 'Brassica_oleracea_TO1000DH3']

primary_species = species_order[0]

single_copy_only = False
one_peak_per_orthogroup = False

# %%
filtered_assigned = []

for tf, group in peak_files_annotated_df.groupby('tf', sort=False):

    if primary_species not in group['species'].values:
        print(f'no peaks file for {primary_species} and tf {tf}. skipped.')
        continue

    peaks_by_species = ReadFilterPeakFiles(group, species_order, peak_filter_params)
    peaks_orthogroups_by_species = AssignOrthogroupsToPeaksBySpecies(peaks_by_species, ortho_table_by_species, single_copy_only, organelle_orthogroups)

    for sp, sp_peak_orthogroups in peaks_orthogroups_by_species.items():
        sp_peak_orthogroups['tf'] = tf
        filtered_assigned.append(sp_peak_orthogroups)
        
filtered_assigned = pd.concat(filtered_assigned)

if one_peak_per_orthogroup:
    ### only keep tallest peak if more than one gene in same species+orthogroup targeted
    filtered_assigned = filtered_assigned.sort_values(by=['species', 'tf', 'orthogroup', 'peak_foldch'])
    filtered_assigned = filtered_assigned.drop_duplicates(subset=['species', 'tf', 'orthogroup'], keep='last')
    
display(filtered_assigned)
# Out:
#          peak_chr  peak_start  peak_end  \
# 0            Chr3    15645684  15646225
# 1            Chr2    15880047  15880573
# 2            Chr3    10891839  10892318
# 3            Chr2      510093    510507
# 4            Chr2      509317    509570
# ...           ...         ...       ...
# 2348  NC_027751.1    23509025  23509194
# 2349  NC_027749.1    51807354  51807590
# 2350  NC_027748.1    13558014  13558212
# 2351  NC_027754.1    32799597  32799741
# 2352  NC_027753.1    32215505  32215652
#
#                                               peak_name  peak_foldch  \
# 0     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.60200
# 1     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.41800
# 2     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    118.30000
# 3     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    112.61500
# 4     AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...      8.80374
# ...                                                 ...          ...
# 2348  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.01157
# 2349  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 2350  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 2351  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 2352  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00470
#
#       peak_pscore  peak_qscore  peak_summit  feature_chr feature_source  ...  \
# 0       1156.4600    1152.0100          268         Chr3   phytozomev12  ...
# 1       1154.2900    1149.8400          224         Chr2   phytozomev12  ...
# 2       1117.4500    1113.0100          250         Chr3   phytozomev12  ...
# 3       1050.7800    1046.3700          200         Chr2   phytozomev12  ...
# 4         31.8545      29.9582          132         Chr2   phytozomev12  ...
# ...           ...          ...          ...          ...            ...  ...
# 2348      12.5290      10.4431           80  NC_027751.1         Gnomon  ...
# 2349      12.8676      10.7759           92  NC_027749.1         Gnomon  ...
# 2350      12.8676      10.7759          113  NC_027748.1         Gnomon  ...
# 2351      12.8676      10.7759           64  NC_027754.1         Gnomon  ...
# 2352      12.5123      10.4268           61  NC_027753.1         Gnomon  ...
#
#      relative_cds_end  summit_to_cds_start  summit_to_cds_end     target_id  \
# 0                -238                 1825                506   AT3G43740.2
# 1                -662                 3102                860   AT2G37940.1
# 2                   0                 1734                250   AT3G28870.1
# 3               -1627                 4770               1139   AT2G02070.2
# 4               -1627                 3926                295   AT2G02070.2
# ...               ...                  ...                ...           ...
# 2348             -120                 5642               1308  LOC106338425
# 2349             -196                 1605               -341  LOC106322916
# 2350             -229                 2871                975  LOC106308684
# 2351             -576                 2742                685  LOC106305797
# 2352             -219                 4459               1450  LOC106299959
#
#                           species  orthogroup      protein_id  \
# 0      Arabidopsis_thaliana_Col-0   OG0011550     AT3G43740.2
# 1      Arabidopsis_thaliana_Col-0   OG0000905     AT2G37940.1
# 2      Arabidopsis_thaliana_Col-0   OG0002896     AT3G28870.1
# 3      Arabidopsis_thaliana_Col-0   OG0003922     AT2G02070.2
# 4      Arabidopsis_thaliana_Col-0   OG0003922     AT2G02070.2
# ...                           ...         ...             ...
# 2348  Brassica_oleracea_TO1000DH3   OG0010530  XP_013632858.1
# 2349  Brassica_oleracea_TO1000DH3   OG0001328  XP_013616525.1
# 2350  Brassica_oleracea_TO1000DH3   OG0009403  XP_013601274.1
# 2351  Brassica_oleracea_TO1000DH3   OG0012067  XP_013597640.1
# 2352  Brassica_oleracea_TO1000DH3   OG0000679  XP_013591440.1
#
#       single_copy_ortho          gene         tf
# 0                 False     AT3G43740  AT1G01060
# 1                 False     AT2G37940  AT1G01060
# 2                 False     AT3G28870  AT1G01060
# 3                 False     AT2G02070  AT1G01060
# 4                 False     AT2G02070  AT1G01060
# ...                 ...           ...        ...
# 2348              False  LOC106338425  AT5G67580
# 2349              False  LOC106322916  AT5G67580
# 2350              False  LOC106308684  AT5G67580
# 2351               True  LOC106305797  AT5G67580
# 2352              False  LOC106299959  AT5G67580
#
# [4931855 rows x 31 columns]

# %%
print(len(filtered_assigned['species'].unique()))
# Out:
# 4

# %%
cons_gene_counts_by_og = filtered_assigned.groupby(['species', 'tf', 'orthogroup'])['gene'].agg('nunique')
# cons_gene_counts_by_og = cons_gene_counts_by_og.reset_index().set_index(['species', 'orthogroup'])
display(cons_gene_counts_by_og.sort_index())
cons_gene_frac_by_og = cons_gene_counts_by_og / orthogroup_sizes
cons_gene_frac_by_og = cons_gene_frac_by_og.dropna()
display(cons_gene_frac_by_og.sort_index())
# Out:
# species                         tf         orthogroup
# Arabidopsis_lyrata_MN47         AT1G01060  OG0000007     1
#                                            OG0000016     1
#                                            OG0000019     1
#                                            OG0000033     1
#                                            OG0000034     2
#                                                         ..
# Capsella_rubella_Monte_Gargano  AT5G67580  OG0022869     1
#                                            OG0022876     1
#                                            OG0022913     1
#                                            OG0022933     1
#                                            OG0022950     1
# Name: gene, Length: 3584560, dtype: int64
# species                         orthogroup  tf
# Arabidopsis_lyrata_MN47         OG0000003   AT1G02230    0.5
#                                             AT1G02250    1.0
#                                             AT1G09540    0.5
#                                             AT1G12260    0.5
#                                             AT1G12610    0.5
#                                                         ...
# Capsella_rubella_Monte_Gargano  OG0022951   AT5G65310    0.5
#                                             AT5G65410    1.0
#                                             AT5G66700    0.5
#                                             AT5G66940    0.5
#                                             AT5G67300    0.5
# Name: gene, Length: 3584560, dtype: float64

# %%
cons_gene_frac_by_og = cons_gene_frac_by_og.rename('og_targeted_frac')
cons_gene_frac_by_og = cons_gene_frac_by_og.to_frame().reset_index()
display(cons_gene_frac_by_og)
# Out:
#                                 species orthogroup         tf  \
# 0               Arabidopsis_lyrata_MN47  OG0000003  AT1G02230
# 1               Arabidopsis_lyrata_MN47  OG0000003  AT1G02250
# 2               Arabidopsis_lyrata_MN47  OG0000003  AT1G09540
# 3               Arabidopsis_lyrata_MN47  OG0000003  AT1G12260
# 4               Arabidopsis_lyrata_MN47  OG0000003  AT1G12610
# ...                                 ...        ...        ...
# 3584555  Capsella_rubella_Monte_Gargano  OG0022951  AT5G65310
# 3584556  Capsella_rubella_Monte_Gargano  OG0022951  AT5G65410
# 3584557  Capsella_rubella_Monte_Gargano  OG0022951  AT5G66700
# 3584558  Capsella_rubella_Monte_Gargano  OG0022951  AT5G66940
# 3584559  Capsella_rubella_Monte_Gargano  OG0022951  AT5G67300
#
#          og_targeted_frac
# 0                     0.5
# 1                     1.0
# 2                     0.5
# 3                     0.5
# 4                     0.5
# ...                   ...
# 3584555               0.5
# 3584556               1.0
# 3584557               0.5
# 3584558               0.5
# 3584559               0.5
#
# [3584560 rows x 4 columns]

# %%
# %%time

data = pd.merge(left=filtered_assigned, right=cons_gene_frac_by_og, on=['species', 'tf', 'orthogroup'], how='left')

dfs_to_concat = []
for tf, tf_group in data.groupby('tf'):
    for sp in species_order:
        sp_targets = tf_group[tf_group['species'] == sp]
        sp_targeted_frac_by_og = sp_targets.set_index('orthogroup')['og_targeted_frac'].to_dict()
        tf_group[f'cons_{sp}'] = tf_group['orthogroup'].map(sp_targeted_frac_by_og).fillna(0)
    dfs_to_concat.append(tf_group)

marked_cons = pd.concat(dfs_to_concat)


cons_col_names = [f'cons_{sp}' for sp in species_order]
for cons_frac_thresh in [0]:
    counted_cons_sp_col_name = f'n_cons_species_minfrac{cons_frac_thresh}'
    
    if cons_frac_thresh == 0:
        cons_above_thresh = marked_cons[cons_col_names] > cons_frac_thresh
    else:
        cons_above_thresh = marked_cons[cons_col_names] >= cons_frac_thresh

    marked_cons[counted_cons_sp_col_name] = cons_above_thresh.sum(axis='columns')

marked_cons['n_species_in_orthogroup'] = marked_cons['orthogroup'].map(n_species_by_orthogroup)

display(marked_cons)
# Out:
#             peak_chr  peak_start  peak_end  \
# 0               Chr3    15645684  15646225
# 1               Chr2    15880047  15880573
# 2               Chr3    10891839  10892318
# 3               Chr2      510093    510507
# 4               Chr2      509317    509570
# ...              ...         ...       ...
# 4931850  NC_027751.1    23509025  23509194
# 4931851  NC_027749.1    51807354  51807590
# 4931852  NC_027748.1    13558014  13558212
# 4931853  NC_027754.1    32799597  32799741
# 4931854  NC_027753.1    32215505  32215652
#
#                                                  peak_name  peak_foldch  \
# 0        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.60200
# 1        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.41800
# 2        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    118.30000
# 3        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    112.61500
# 4        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...      8.80374
# ...                                                    ...          ...
# 4931850  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.01157
# 4931851  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931852  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931853  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931854  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00470
#
#          peak_pscore  peak_qscore  peak_summit  feature_chr feature_source  \
# 0          1156.4600    1152.0100          268         Chr3   phytozomev12
# 1          1154.2900    1149.8400          224         Chr2   phytozomev12
# 2          1117.4500    1113.0100          250         Chr3   phytozomev12
# 3          1050.7800    1046.3700          200         Chr2   phytozomev12
# 4            31.8545      29.9582          132         Chr2   phytozomev12
# ...              ...          ...          ...          ...            ...
# 4931850      12.5290      10.4431           80  NC_027751.1         Gnomon
# 4931851      12.8676      10.7759           92  NC_027749.1         Gnomon
# 4931852      12.8676      10.7759          113  NC_027748.1         Gnomon
# 4931853      12.8676      10.7759           64  NC_027754.1         Gnomon
# 4931854      12.5123      10.4268           61  NC_027753.1         Gnomon
#
#          ... single_copy_ortho          gene         tf og_targeted_frac  \
# 0        ...             False     AT3G43740  AT1G01060         1.000000
# 1        ...             False     AT2G37940  AT1G01060         0.500000
# 2        ...             False     AT3G28870  AT1G01060         0.500000
# 3        ...             False     AT2G02070  AT1G01060         1.000000
# 4        ...             False     AT2G02070  AT1G01060         1.000000
# ...      ...               ...           ...        ...              ...
# 4931850  ...             False  LOC106338425  AT5G67580         0.500000
# 4931851  ...             False  LOC106322916  AT5G67580         0.250000
# 4931852  ...             False  LOC106308684  AT5G67580         0.500000
# 4931853  ...              True  LOC106305797  AT5G67580         1.000000
# 4931854  ...             False  LOC106299959  AT5G67580         0.285714
#
#         cons_Arabidopsis_thaliana_Col-0  cons_Arabidopsis_lyrata_MN47  \
# 0                                   1.0                           0.0
# 1                                   0.5                           0.5
# 2                                   0.5                           0.0
# 3                                   1.0                           1.0
# 4                                   1.0                           1.0
# ...                                 ...                           ...
# 4931850                             0.0                           0.0
# 4931851                             0.0                           0.0
# 4931852                             0.0                           0.0
# 4931853                             0.0                           0.0
# 4931854                             0.0                           0.0
#
#          cons_Capsella_rubella_Monte_Gargano  \
# 0                                        0.0
# 1                                        0.5
# 2                                        0.0
# 3                                        1.0
# 4                                        1.0
# ...                                      ...
# 4931850                                  0.0
# 4931851                                  0.0
# 4931852                                  0.0
# 4931853                                  0.0
# 4931854                                  0.0
#
#          cons_Brassica_oleracea_TO1000DH3 n_cons_species_minfrac0  \
# 0                                0.000000                       1
# 1                                0.000000                       3
# 2                                0.000000                       1
# 3                                0.000000                       3
# 4                                0.000000                       3
# ...                                   ...                     ...
# 4931850                          0.500000                       1
# 4931851                          0.250000                       1
# 4931852                          0.500000                       1
# 4931853                          1.000000                       1
# 4931854                          0.285714                       1
#
#         n_species_in_orthogroup
# 0                             3
# 1                             4
# 2                             4
# 3                             4
# 4                             4
# ...                         ...
# 4931850                       4
# 4931851                       4
# 4931852                       4
# 4931853                       4
# 4931854                       4
#
# [4931855 rows x 38 columns]
# CPU times: user 14.2 s, sys: 8.52 s, total: 22.7 s
# Wall time: 22.8 s

# %%
## Adding clade aware conservation values to df

def n_cons_species_by_clade(row):
    ath = row['cons_Arabidopsis_thaliana_Col-0']
    aly = row['cons_Arabidopsis_lyrata_MN47']
    cru = row['cons_Capsella_rubella_Monte_Gargano']
    bol = row['cons_Brassica_oleracea_TO1000DH3']

    if (ath > 0) & (aly > 0) & (cru > 0) & (bol > 0):
        conservation = 4
    elif (ath > 0) & (aly > 0) & (cru > 0):
        conservation = 3
    elif (ath > 0) & (aly > 0):
        conservation = 2        
    else:
        conservation = 1

    return conservation        


marked_cons = marked_cons.assign(n_cons_species_clade_aware=marked_cons.apply(lambda row: n_cons_species_by_clade(row), axis=1))

display(marked_cons)
# Out:
#             peak_chr  peak_start  peak_end  \
# 0               Chr3    15645684  15646225
# 1               Chr2    15880047  15880573
# 2               Chr3    10891839  10892318
# 3               Chr2      510093    510507
# 4               Chr2      509317    509570
# ...              ...         ...       ...
# 4931850  NC_027751.1    23509025  23509194
# 4931851  NC_027749.1    51807354  51807590
# 4931852  NC_027748.1    13558014  13558212
# 4931853  NC_027754.1    32799597  32799741
# 4931854  NC_027753.1    32215505  32215652
#
#                                                  peak_name  peak_foldch  \
# 0        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.60200
# 1        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    121.41800
# 2        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    118.30000
# 3        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...    112.61500
# 4        AT1G01060_A_thaliana_Col-0_DAPi709D10-ORGi5005...      8.80374
# ...                                                    ...          ...
# 4931850  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.01157
# 4931851  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931852  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931853  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00698
# 4931854  AT5G67580_B_oleracea_TO1000DH3_DAPi711D05-ORGi...      5.00470
#
#          peak_pscore  peak_qscore  peak_summit  feature_chr feature_source  \
# 0          1156.4600    1152.0100          268         Chr3   phytozomev12
# 1          1154.2900    1149.8400          224         Chr2   phytozomev12
# 2          1117.4500    1113.0100          250         Chr3   phytozomev12
# 3          1050.7800    1046.3700          200         Chr2   phytozomev12
# 4            31.8545      29.9582          132         Chr2   phytozomev12
# ...              ...          ...          ...          ...            ...
# 4931850      12.5290      10.4431           80  NC_027751.1         Gnomon
# 4931851      12.8676      10.7759           92  NC_027749.1         Gnomon
# 4931852      12.8676      10.7759          113  NC_027748.1         Gnomon
# 4931853      12.8676      10.7759           64  NC_027754.1         Gnomon
# 4931854      12.5123      10.4268           61  NC_027753.1         Gnomon
#
#          ...          gene         tf  og_targeted_frac  \
# 0        ...     AT3G43740  AT1G01060          1.000000
# 1        ...     AT2G37940  AT1G01060          0.500000
# 2        ...     AT3G28870  AT1G01060          0.500000
# 3        ...     AT2G02070  AT1G01060          1.000000
# 4        ...     AT2G02070  AT1G01060          1.000000
# ...      ...           ...        ...               ...
# 4931850  ...  LOC106338425  AT5G67580          0.500000
# 4931851  ...  LOC106322916  AT5G67580          0.250000
# 4931852  ...  LOC106308684  AT5G67580          0.500000
# 4931853  ...  LOC106305797  AT5G67580          1.000000
# 4931854  ...  LOC106299959  AT5G67580          0.285714
#
#         cons_Arabidopsis_thaliana_Col-0 cons_Arabidopsis_lyrata_MN47  \
# 0                                   1.0                          0.0
# 1                                   0.5                          0.5
# 2                                   0.5                          0.0
# 3                                   1.0                          1.0
# 4                                   1.0                          1.0
# ...                                 ...                          ...
# 4931850                             0.0                          0.0
# 4931851                             0.0                          0.0
# 4931852                             0.0                          0.0
# 4931853                             0.0                          0.0
# 4931854                             0.0                          0.0
#
#          cons_Capsella_rubella_Monte_Gargano  \
# 0                                        0.0
# 1                                        0.5
# 2                                        0.0
# 3                                        1.0
# 4                                        1.0
# ...                                      ...
# 4931850                                  0.0
# 4931851                                  0.0
# 4931852                                  0.0
# 4931853                                  0.0
# 4931854                                  0.0
#
#          cons_Brassica_oleracea_TO1000DH3  n_cons_species_minfrac0  \
# 0                                0.000000                        1
# 1                                0.000000                        3
# 2                                0.000000                        1
# 3                                0.000000                        3
# 4                                0.000000                        3
# ...                                   ...                      ...
# 4931850                          0.500000                        1
# 4931851                          0.250000                        1
# 4931852                          0.500000                        1
# 4931853                          1.000000                        1
# 4931854                          0.285714                        1
#
#         n_species_in_orthogroup n_cons_species_clade_aware
# 0                             3                          1
# 1                             4                          3
# 2                             4                          1
# 3                             4                          3
# 4                             4                          3
# ...                         ...                        ...
# 4931850                       4                          1
# 4931851                       4                          1
# 4931852                       4                          1
# 4931853                       4                          1
# 4931854                       4                          1
#
# [4931855 rows x 39 columns]

# %%
len(marked_cons['tf'].unique())
# Out:
# 244

# %%
marked_cons.groupby('species')['n_cons_species_minfrac0'].mean()
# Out:
# species
# Arabidopsis_lyrata_MN47           2.275459
# Arabidopsis_thaliana_Col-0        2.372941
# Brassica_oleracea_TO1000DH3       1.867600
# Capsella_rubella_Monte_Gargano    2.262421
# Name: n_cons_species_minfrac0, dtype: float64

# %%
outfile_name = 'N4_filtered-annotated-peaks_minfoldch5_3prime_minus-500bp-to-plus-2000bp.tsv'

print(outfile_name)
marked_cons.to_csv(outfile_name, sep='\t', index=False)
# Out:
# N4_filtered-annotated-peaks_minfoldch5_3prime_minus-500bp-to-plus-2000bp.tsv
